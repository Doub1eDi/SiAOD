# %% [markdown]
# # Лабораторная работа №1
# ## Выполнила студентка грауппы БСТ2002 Тулаева Диана Павловна
# ### Задание №1

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Задание №2

# %% [markdown]
# #### Написать генератор случайных матриц(многомерных), который принимает опциональные параметры m, n, min_limit, max_limit, где m и n указывают размер матрицы, а min_lim и max_lim - минимальное и максимальное значение для генерируемого числа . По умолчанию при отсутствии параметров принимать следующие значения: m = 50 n = 50 min_limit = -250 max_limit = 1000 + (номер своего варианта)

# %%
import random
from random import randint
import copy
import math
import time
import pandas as pd

# %%
def Matrix(A):
    
    if A.lower() == "да":
        m = int(input("Количество строк: "))
        n = int(input("Количество столбцов: "))
        min_limit = int(input("Минимальное число: "))
        max_limit = int(input("Максимальное число: "))
        matrix = [[randint(min_limit, max_limit) for j in range (n)] for i in range(m)]
        return matrix
    else:
        m = 50
        n = 50
        min_limit = -250
        max_limit = 1018
        matrix = [[randint(min_limit, max_limit) for j in range(n)]for i in range(m)]
        return matrix

# %% [markdown]
# ### Задание №3

# %% [markdown]
# #### Реализовать методы сортировки строк числовой матрицы в соответствии с заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со временем стандартной функции сортировки. Испытания проводить на сгенерированных матрицах.

# %% [markdown]
# ### Выбором

# %%
def selectionSort(matrix):
    for row in matrix:
        for i in range(len(row)):
            smallest = i
            for j in range(i + 1, len(row)):
                if row[j] < row[smallest]:
                    smallest = j
            row[i], row[smallest] = row[smallest], row[i]

# %% [markdown]
# ### Вставкой

# %%
def insertionSort(matrix):
    for g in range (len(matrix)):
        for i in range (1,len(matrix[0])):
            key = matrix[g][i]
            j = i - 1
            while j >= 0 and key < matrix[g][j]:
                matrix[g][j + 1] = matrix[g][j]
                j -= 1
                matrix[g][j + 1] = key
    return matrix

# %% [markdown]
# ### Обменом

# %%
def bubbleSort (matrix):
    for g in range (len(matrix)):
        for i in range (len(matrix[0])-1):
            for j in range (len(matrix[0]) - i - 1):
                if matrix[g][j] > matrix[g][j + 1]:
                     matrix[g][j], matrix[g][j + 1] = matrix[g][j + 1], matrix[g][j]
    return matrix

# %% [markdown]
# ### Шелла

# %%
def shellSort(matrix):
    for i in range(len(matrix)):
        d = int(len(matrix[i]) / 2)
        while d > 0:
            for j in range(len(matrix[i])):
                for h in range(int(j + d),len(matrix[i]),d):
                    if matrix[i][j] > matrix[i][h]:
                        temp = matrix[i][j]
                        matrix[i][j] = matrix[i][h]
                        matrix[i][h] = temp
            
            d = int(d / 2)
    return matrix

# %% [markdown]
# ### Турнирная

# %%
def tournamentSort(matrix):
    for i in range(len(matrix)):
        ttournamentSort(matrix[i])
    return matrix
def ttournamentSort(matrix):
    tree = [None] * 2 * (len(matrix) + len(matrix) % 2)
    index = len(tree) - len(matrix) - len(matrix) % 2
    
    for i, v in enumerate(matrix):
        tree[index + i] = (i, v)
    
    for j in range(len(matrix)):
        n = len(matrix)
        index = len(tree) - len(matrix) - len(matrix) % 2
        while index > -1:
            n = (n + 1) // 2
            for i in range(n):
                i = max(index + i * 2, 1) 
                if tree[i] != None and tree[i + 1] != None:
                    if tree[i][1] < tree[i + 1][1]:
                        tree[i // 2] = tree[i]
                    else:
                        tree[i // 2] = tree[i + 1]
                else:
                    tree[i // 2] = tree[i] if tree[i] != None else tree[i + 1]
            index -= n

        index, x = tree[0]
        matrix[j] = x
        tree[len(tree) - len(matrix) - len(matrix) % 2 + index] = None

# %% [markdown]
# ### Быстрая

# %%
def quickSort(matrix):
    for i in range(len(matrix)):
        qquickSort(0, len(matrix[i]) -1, matrix, i)
    return matrix

def qquickSort(_first, _last, matrix, row):
    first = int(_first)
    last = int(_last)
    middle = int((first + last) / 2)
    
    while (first < last):
        
        while( matrix[row][first] < matrix[row][middle]): 
            first += 1
        while( matrix[row][last] > matrix[row][middle]):
            last -= 1
        if(first <= last):
            matrix[row][first], matrix[row][last] = matrix[row][last], matrix[row][first]
            first += 1
            last -= 1
    
    if(_first < last):
        qquickSort(_first, last, matrix,row)
    if(first < _last):
        qquickSort(first, _last, matrix, row)

# %% [markdown]
# ### Пирамидальная

# %%
def heapify(matrix, n, i):
    largest = i
    l = 2 * i + 1
    r = 2 * i + 2

    if l < n and matrix[i] < matrix[l]:
        largest = l

    if r < n and matrix[largest] < matrix[r]:
        largest = r

    if largest != i:
        matrix[i], matrix[largest] = matrix[largest], matrix[i]

        heapify(matrix, n, largest)
def heapSort(matrix):

    for i in range(len(matrix)):
        n = len(matrix[i])

        for j in range(n, -1, -1):
            heapify(matrix[i], n, j)

        for j in range(n - 1, 0, -1):
            matrix[i][j], matrix[i][0] = matrix[i][0], matrix[i][j] 
            heapify(matrix[i], j, 0)
    return matrix

# %% [markdown]
# ### Стандартная

# %%
def standartSort(matrix): 
    matrix.sort()
    return matrix

# %% [markdown]
# ### Матрица

# %%
A = input("Хотите ввести параметры матрицы? ")
matrix = Matrix(A)
print("Матрица:")
for i in range (len(matrix)):
    print(matrix[i])
# Out:
# Хотите ввести параметры матрицы? нет
# Матрица:
# [773, 9, 879, 569, 299, 484, 422, 452, 993, -221, 175, 980, 484, -63, -168, -166, 199, 353, 876, 512, -194, 437, -27, 595, 514, -69, -26, -52, 413, 497, -25, 767, 761, 62, 340, 905, 608, 976, 794, 255, 385, 182, 755, 511, 142, 851, 6, 30, -159, 306]
# [557, 729, 389, 688, -134, 488, 473, 906, 220, -136, 700, 445, 374, 938, 355, 350, 991, 75, -113, 839, 712, 753, -246, 493, 742, 342, 376, 924, -216, 576, -195, 495, 337, -8, 394, 207, 745, 745, -84, -229, 867, -159, 139, 316, 815, 623, 333, 144, 579, 393]
# [558, 1006, -239, 713, 635, 271, 774, -154, -93, -233, 697, 782, 133, 517, -135, -26, -43, -140, -78, 954, 558, -78, 111, 574, 167, 631, 641, 559, 201, 954, -20, 983, 26, 161, 328, 91, 472, 844, 748, 421, 640, 344, 540, 230, -73, 176, 181, 82, 671, 625]
# ...

# %%
selection_sort = copy.deepcopy(matrix)
A = time.time()
selectionSort(selection_sort)
B = time.time() - A
print("Сортировка выбором")

for i in range(len(selection_sort)):
    print(selection_sort[i])   
print("Выполнена за:",'%.8f' % B,"секунд")
# Out:
# Сортировка выбором
# [-221, -194, -168, -166, -159, -69, -63, -52, -27, -26, -25, 6, 9, 30, 62, 142, 175, 182, 199, 255, 299, 306, 340, 353, 385, 413, 422, 437, 452, 484, 484, 497, 511, 512, 514, 569, 595, 608, 755, 761, 767, 773, 794, 851, 876, 879, 905, 976, 980, 993]
# [-246, -229, -216, -195, -159, -136, -134, -113, -84, -8, 75, 139, 144, 207, 220, 316, 333, 337, 342, 350, 355, 374, 376, 389, 393, 394, 445, 473, 488, 493, 495, 557, 576, 579, 623, 688, 700, 712, 729, 742, 745, 745, 753, 815, 839, 867, 906, 924, 938, 991]
# [-239, -233, -154, -140, -135, -93, -78, -78, -73, -43, -26, -20, 26, 82, 91, 111, 133, 161, 167, 176, 181, 201, 230, 271, 328, 344, 421, 472, 517, 540, 558, 558, 559, 574, 625, 631, 635, 640, 641, 671, 697, 713, 748, 774, 782, 844, 954, 954, 983, 1006]
# ...

# %%
insertion_sort = copy.deepcopy(matrix)
A = time.time()
insertionSort(insertion_sort)
B = time.time() - A
print("Сортировка вставкой")

for i in range(len(insertion_sort)):
    print(insertion_sort[i])   
print("Выполнена за:",'%.8f' % B,"секунд")
# Out:
# Сортировка вставкой
# [-221, -194, -168, -166, -159, -69, -63, -52, -27, -26, -25, 6, 9, 30, 62, 142, 175, 182, 199, 255, 299, 306, 340, 353, 385, 413, 422, 437, 452, 484, 484, 497, 511, 512, 514, 569, 595, 608, 755, 761, 767, 773, 794, 851, 876, 879, 905, 976, 980, 993]
# [-246, -229, -216, -195, -159, -136, -134, -113, -84, -8, 75, 139, 144, 207, 220, 316, 333, 337, 342, 350, 355, 374, 376, 389, 393, 394, 445, 473, 488, 493, 495, 557, 576, 579, 623, 688, 700, 712, 729, 742, 745, 745, 753, 815, 839, 867, 906, 924, 938, 991]
# [-239, -233, -154, -140, -135, -93, -78, -78, -73, -43, -26, -20, 26, 82, 91, 111, 133, 161, 167, 176, 181, 201, 230, 271, 328, 344, 421, 472, 517, 540, 558, 558, 559, 574, 625, 631, 635, 640, 641, 671, 697, 713, 748, 774, 782, 844, 954, 954, 983, 1006]
# ...

# %%
bubble_sort = copy.deepcopy(matrix)
A = time.time()
bubbleSort(bubble_sort)
B = time.time() - A
print("Сортировка обменом")

for i in range(len(bubble_sort)):
    print(bubble_sort[i])   
print("Выполнена за:",'%.8f' % B,"секунд")
# Out:
# Сортировка обменом
# [-221, -194, -168, -166, -159, -69, -63, -52, -27, -26, -25, 6, 9, 30, 62, 142, 175, 182, 199, 255, 299, 306, 340, 353, 385, 413, 422, 437, 452, 484, 484, 497, 511, 512, 514, 569, 595, 608, 755, 761, 767, 773, 794, 851, 876, 879, 905, 976, 980, 993]
# [-246, -229, -216, -195, -159, -136, -134, -113, -84, -8, 75, 139, 144, 207, 220, 316, 333, 337, 342, 350, 355, 374, 376, 389, 393, 394, 445, 473, 488, 493, 495, 557, 576, 579, 623, 688, 700, 712, 729, 742, 745, 745, 753, 815, 839, 867, 906, 924, 938, 991]
# [-239, -233, -154, -140, -135, -93, -78, -78, -73, -43, -26, -20, 26, 82, 91, 111, 133, 161, 167, 176, 181, 201, 230, 271, 328, 344, 421, 472, 517, 540, 558, 558, 559, 574, 625, 631, 635, 640, 641, 671, 697, 713, 748, 774, 782, 844, 954, 954, 983, 1006]
# ...

# %%
shell_sort = copy.deepcopy(matrix)
A = time.time()
shellSort(shell_sort)
B = time.time() - A
print("Сортировка Шелла")

for i in range(len(shell_sort)):
    print(shell_sort[i])   
print("Выполнена за:",'%.8f' % B,"секунд")
# Out:
# Сортировка Шелла
# [-221, -194, -168, -166, -159, -69, -63, -52, -27, -26, -25, 6, 9, 30, 62, 142, 175, 182, 199, 255, 299, 306, 340, 353, 385, 413, 422, 437, 452, 484, 484, 497, 511, 512, 514, 569, 595, 608, 755, 761, 767, 773, 794, 851, 876, 879, 905, 976, 980, 993]
# [-246, -229, -216, -195, -159, -136, -134, -113, -84, -8, 75, 139, 144, 207, 220, 316, 333, 337, 342, 350, 355, 374, 376, 389, 393, 394, 445, 473, 488, 493, 495, 557, 576, 579, 623, 688, 700, 712, 729, 742, 745, 745, 753, 815, 839, 867, 906, 924, 938, 991]
# [-239, -233, -154, -140, -135, -93, -78, -78, -73, -43, -26, -20, 26, 82, 91, 111, 133, 161, 167, 176, 181, 201, 230, 271, 328, 344, 421, 472, 517, 540, 558, 558, 559, 574, 625, 631, 635, 640, 641, 671, 697, 713, 748, 774, 782, 844, 954, 954, 983, 1006]
# ...

# %%
tournament_sort = copy.deepcopy(matrix)
A = time.time()
tournamentSort(tournament_sort)
B = time.time() - A
print("Сортировка турнирная")

for i in range(len(tournament_sort)):
    print(tournament_sort[i])   
print("Выполнена за:",'%.8f' % B,"секунд")
# Out:
# Сортировка турнирная
# [9, -221, -221, -194, -194, -168, -168, -166, -166, -159, -159, -69, -69, -63, -63, -52, -52, -27, -27, -26, -26, -25, -25, 6, 6, 30, 30, 62, 62, 142, 142, 175, 175, 182, 182, 199, 199, 255, 255, 299, 306, 306, 340, 340, 353, 353, 385, 385, 413, 413]
# [-134, -246, -246, -229, -229, -216, -216, -195, -195, -159, -159, -136, -136, -113, -113, -84, -84, -8, -8, 75, 75, 139, 139, 144, 144, 207, 207, 220, 220, 316, 316, 333, 333, 337, 337, 342, 342, 350, 350, 355, 355, 374, 374, 376, 376, 389, 393, 393, 394, 394]
# [-239, -233, -233, -154, -140, -140, -135, -135, -93, -93, -78, -78, -78, -78, -73, -73, -43, -43, -26, -26, -20, -20, 26, 26, 82, 82, 91, 91, 111, 111, 133, 133, 161, 161, 167, 167, 176, 176, 181, 181, 201, 201, 230, 230, 271, 328, 328, 344, 344, 421]
# ...

# %%
quick_sort = copy.deepcopy(matrix)
A = time.time()
quickSort(quick_sort)
B = time.time() - A
print("Сортировка быстрая")

for i in range(len(quick_sort)):
    print(quick_sort[i])   
print("Выполнена за:",'%.8f' % B,"секунд")
# Out:
# Сортировка быстрая
# [-221, -194, -166, -159, -27, -168, -69, -52, -26, -25, -63, 142, 6, 9, 30, 62, 175, 182, 199, 255, 299, 306, 353, 340, 385, 437, 422, 452, 484, 484, 511, 512, 413, 497, 514, 608, 569, 595, 755, 761, 767, 794, 773, 851, 876, 879, 905, 976, 980, 993]
# [-246, -229, -216, -195, -159, -134, -136, -113, -84, -8, 75, 139, 144, 350, 207, 220, 316, 333, 355, 374, 389, 393, 445, 473, 488, 493, 557, 579, 623, 688, 700, 712, 729, 337, 342, 376, 394, 495, 576, 742, 745, 745, 753, 815, 839, 867, 906, 924, 938, 991]
# [-239, -233, -140, -135, -78, -78, -73, -154, -93, -20, 26, 82, 91, 161, -43, -26, 111, 133, 167, 517, 558, 574, 176, 181, 201, 559, 631, 641, 230, 271, 328, 558, 625, 635, 671, 697, 344, 472, 540, 421, 640, 748, 713, 774, 782, 844, 954, 954, 983, 1006]
# ...

# %%
heap_sort = copy.deepcopy(matrix)
A = time.time()
heapSort(heap_sort)
B = time.time() - A
print("Сортировка пирамидальная")

for i in range(len(heap_sort)):
    print(heap_sort[i])   
print("Выполнена за:",'%.8f' % B,"секунд")
# Out:
# Сортировка пирамидальная
# [-221, -194, -168, -166, -159, -69, -63, -52, -27, -26, -25, 6, 9, 30, 62, 142, 175, 182, 199, 255, 299, 306, 340, 353, 385, 413, 422, 437, 452, 484, 484, 497, 511, 512, 514, 569, 595, 608, 755, 761, 767, 773, 794, 851, 876, 879, 905, 976, 980, 993]
# [-246, -229, -216, -195, -159, -136, -134, -113, -84, -8, 75, 139, 144, 207, 220, 316, 333, 337, 342, 350, 355, 374, 376, 389, 393, 394, 445, 473, 488, 493, 495, 557, 576, 579, 623, 688, 700, 712, 729, 742, 745, 745, 753, 815, 839, 867, 906, 924, 938, 991]
# [-239, -233, -154, -140, -135, -93, -78, -78, -73, -43, -26, -20, 26, 82, 91, 111, 133, 161, 167, 176, 181, 201, 230, 271, 328, 344, 421, 472, 517, 540, 558, 558, 559, 574, 625, 631, 635, 640, 641, 671, 697, 713, 748, 774, 782, 844, 954, 954, 983, 1006]
# ...

# %%
A = time.time()
matrix.sort()
B = time.time() - A
print("Стандартная сортировка ") 
print("Выполнена за:",'%.8f' % B,"секунд")
# Out:
# Стандартная сортировка
# Выполнена за: 0.00102234 секунд
